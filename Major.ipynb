# %% [markdown]
# <a href="https://colab.research.google.com/github/Yaminidhimann/PROJECT/blob/main/Major.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class MenuItem:
    def __init__(self, name, price):
        self.name = name
        self.price = price

class FoodItem(MenuItem):
    def __init__(self, name, price):
        MenuItem.__init__(self, name, price)

class DrinkItem(MenuItem):
    def __init__(self, name, price):
        MenuItem.__init__(self, name, price)

class Order:
    def __init__(self):
        self.items = []

    def add_item(self, item):
        self.items.append(item)

    def remove_item(self, item):
        if item in self.items:
            self.items.remove(item)

    def total_price(self):
        return sum(item.price for item in self.items)

class Menu:
    def __init__(self):
        self.menu_items = {}

    def add_item(self, item):
        self.menu_items[item.name] = item

    def display_menu(self):
        for name, item in self.menu_items.items():
            print(f"{name}: ${item.price}")

menu = Menu()
menu.add_item(FoodItem("Pizza", 10))
menu.add_item(FoodItem("chai", 8))
menu.add_item(FoodItem("Maggie", 6))
menu.add_item(DrinkItem("Coke", 2))
menu.add_item(DrinkItem("Coffee", 3))

order = Order()

print("Welcome to our restaurant!")
while True:
    print("\nMenu:")
    menu.display_menu()
    print("\n1. Add item to order")
    print("2. Remove item from order")
    print("3. View order")
    print("4. Checkout")
    print("5. Exit")

    choice = input("\nEnter your choice: ")

    if choice == "1":
        item_name = input("Enter the name of the item you want to add: ")
        if item_name in menu.menu_items:
            order.add_item(menu.menu_items[item_name])
            print(f"{item_name} added to order.")
        else:
            print("Item not found in menu.")

    elif choice == "2":
        item_name = input("Enter the name of the item you want to remove: ")
        if item_name in menu.menu_items:
            order.remove_item(menu.menu_items[item_name])
            print(f"{item_name} removed from order.")
        else:
            print("Item not found in menu.")

    elif choice == "3":
        print("\nYour order:")
        for item in order.items:
            print(f"{item.name}: ${item.price}")
        print(f"Total price: ${order.total_price()}")

    elif choice == "4":
        print("\nThank you for your order! Your total is $", order.total_price())
        break

    elif choice == "5":
        print("Thank you for visiting our restaurant! Goodbye!")
        break

    else:
        print("Invalid choice. Please enter a number between 1 and 5.")
# Out:
# Welcome to our restaurant!
#
# Menu:
# Pizza: $10
# chai: $8
# Maggie: $6
# Coke: $2
# Coffee: $3
#
# 1. Add item to order
# 2. Remove item from order
# 3. View order
# 4. Checkout
# 5. Exit
#
# Enter your choice: 3
#
# Your order:
# Total price: $0
#
# Menu:
# Pizza: $10
# chai: $8
# Maggie: $6
# Coke: $2
# Coffee: $3
#
# 1. Add item to order
# 2. Remove item from order
# 3. View order
# 4. Checkout
# 5. Exit
#
# Enter your choice: 1
# Enter the name of the item you want to add: 3
# Item not found in menu.
#
# Menu:
# Pizza: $10
# chai: $8
# Maggie: $6
# Coke: $2
# Coffee: $3
#
# 1. Add item to order
# 2. Remove item from order
# 3. View order
# 4. Checkout
# 5. Exit
#
# Enter your choice: 3
#
# Your order:
# Total price: $0
#
# Menu:
# Pizza: $10
# chai: $8
# Maggie: $6
# Coke: $2
# Coffee: $3
#
# 1. Add item to order
# 2. Remove item from order
# 3. View order
# 4. Checkout
# 5. Exit
#
# Enter your choice: 3
#
# Your order:
# Total price: $0
#
# Menu:
# Pizza: $10
# chai: $8
# Maggie: $6
# Coke: $2
# Coffee: $3
#
# 1. Add item to order
# 2. Remove item from order
# 3. View order
# 4. Checkout
# 5. Exit
